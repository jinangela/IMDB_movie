# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
predictions = pd.read_csv("runs/1502733292/prediction.csv", header=None)

# %%
predictions.columns = dev.columns
predictions.set_index(dev.index, inplace=True)

# %%
predictions.head()
# Out:
#                                                                              storyline  \
# movie_title
# Spectre                              a cryptic message from the past sends james bo...
# Avengers: Age of Ultron              tony stark creates the ultron program to prote...
# Batman v Superman: Dawn of Justice   the general public is concerned over having su...
# Captain America: Civil War           with many people fearing the actions of super ...
# Jurassic World                       22 years after the original jurassic park fail...
#
#                                      Drama  Comedy  Thriller  Action  Romance  \
# movie_title
# Spectre                             0.0296  0.1433    0.0073  0.1383   0.0003
# Avengers: Age of Ultron             0.3461  0.0345    0.0000  0.0028   0.5990
# Batman v Superman: Dawn of Justice  0.0013  0.0000    0.0000  0.9972   0.0014
# Captain America: Civil War          0.0750  0.3217    0.0190  0.0161   0.5538
# Jurassic World                      0.2570  0.0003    0.0000  0.0002   0.0001
#
#                                      Adventure  Crime  Sci-Fi  Fantasy  \
# movie_title
# Spectre                                 0.0000 0.0079  0.5484   0.0019
# Avengers: Age of Ultron                 0.0017 0.0008  0.0003   0.0146
# Batman v Superman: Dawn of Justice      0.0000 0.0000  0.0001   0.0000
# Captain America: Civil War              0.0001 0.0000  0.0000   0.0139
# Jurassic World                          0.7108 0.0000  0.0000   0.0001
#
#                                       ...    Biography  Animation  Music  \
# movie_title                           ...
# Spectre                               ...       0.0001     0.1226 0.0000
# Avengers: Age of Ultron               ...       0.0000     0.0000 0.0001
# Batman v Superman: Dawn of Justice    ...       0.0000     0.0000 0.0000
# Captain America: Civil War            ...       0.0000     0.0000 0.0000
# Jurassic World                        ...       0.0000     0.0001 0.0000
#
#                                        War  History  Sport  Musical  \
# movie_title
# Spectre                             0.0000   0.0000 0.0001   0.0000
# Avengers: Age of Ultron             0.0000   0.0000 0.0000   0.0001
# Batman v Superman: Dawn of Justice  0.0000   0.0000 0.0000   0.0000
# Captain America: Civil War          0.0000   0.0000 0.0000   0.0000
# Jurassic World                      0.0000   0.0000 0.0000   0.0000
#
#                                      Documentary  Western  Others
# movie_title
# Spectre                                   0.0000   0.0000  0.0000
# Avengers: Age of Ultron                   0.0000   0.0000  0.0000
# Batman v Superman: Dawn of Justice        0.0000   0.0000  0.0000
# Captain America: Civil War                0.0000   0.0000  0.0000
# Jurassic World                            0.0000   0.0000  0.0000
#
# [5 rows x 23 columns]

# %%
pred_binary = predictions[predictions.columns[1:]].applymap(lambda x: 1 if x > 0.0001 else 0)

# %%
predictions.loc['Kung Fu Panda 3\xc2\xa0']
# Out:
# storyline      when po 's long lost panda father suddenly rea...
# Drama                                                     0.0001
# Comedy                                                    0.5567
# Thriller                                                  0.0708
# Action                                                    0.3721
# Romance                                                   0.0000
# Adventure                                                 0.0000
# Crime                                                     0.0000
# Sci-Fi                                                    0.0000
# Fantasy                                                   0.0002
# Horror                                                    0.0001
# Family                                                    0.0000
# Mystery                                                   0.0000
# Biography                                                 0.0000
# Animation                                                 0.0000
# Music                                                     0.0000
# War                                                       0.0000
# History                                                   0.0000
# Sport                                                     0.0000
# Musical                                                   0.0000
# Documentary                                               0.0000
# Western                                                   0.0000
# Others                                                    0.0000
# Name: Kung Fu Panda 3 , dtype: object

# %%
pred_binary.loc['Kung Fu Panda 3\xc2\xa0']
# Out:
# Drama          1
# Comedy         1
# Thriller       1
# Action         1
# Romance        0
# Adventure      0
# Crime          0
# Sci-Fi         0
# Fantasy        1
# Horror         1
# Family         0
# Mystery        0
# Biography      0
# Animation      0
# Music          0
# War            0
# History        0
# Sport          0
# Musical        0
# Documentary    0
# Western        0
# Others         0
# Name: Kung Fu Panda 3 , dtype: int64

# %%
dev = pd.read_csv("../../01_Data/Outputs/storyline_with_genres_test.csv")

# %%
dev.set_index(['movie_title'], inplace=True)

# %%
dev.head()
# Out:
#                                                                              storyline  \
# movie_title
# Spectre                              A cryptic message from the past sends James Bo...
# Avengers: Age of Ultron              Tony Stark creates the Ultron Program to prote...
# Batman v Superman: Dawn of Justice   The general public is concerned over having Su...
# Captain America: Civil War           With many people fearing the actions of super ...
# Jurassic World                       22 years after the original Jurassic Park fail...
#
#                                      Drama  Comedy  Thriller  Action  Romance  \
# movie_title
# Spectre                                  0       0         1       1        0
# Avengers: Age of Ultron                  0       0         0       1        0
# Batman v Superman: Dawn of Justice       0       0         0       1        0
# Captain America: Civil War               0       0         0       1        0
# Jurassic World                           0       0         1       1        0
#
#                                      Adventure  Crime  Sci-Fi  Fantasy  \
# movie_title
# Spectre                                      1      0       0        0
# Avengers: Age of Ultron                      1      0       1        0
# Batman v Superman: Dawn of Justice           1      0       1        0
# Captain America: Civil War                   1      0       1        0
# Jurassic World                               1      0       1        0
#
#                                       ...    Biography  Animation  Music  War  \
# movie_title                           ...
# Spectre                               ...            0          0      0    0
# Avengers: Age of Ultron               ...            0          0      0    0
# Batman v Superman: Dawn of Justice    ...            0          0      0    0
# Captain America: Civil War            ...            0          0      0    0
# Jurassic World                        ...            0          0      0    0
#
#                                      History  Sport  Musical  Documentary  \
# movie_title
# Spectre                                    0      0        0            0
# Avengers: Age of Ultron                    0      0        0            0
# Batman v Superman: Dawn of Justice         0      0        0            0
# Captain America: Civil War                 0      0        0            0
# Jurassic World                             0      0        0            0
#
#                                      Western  Others
# movie_title
# Spectre                                    0       0
# Avengers: Age of Ultron                    0       0
# Batman v Superman: Dawn of Justice         0       0
# Captain America: Civil War                 0       0
# Jurassic World                             0       0
#
# [5 rows x 23 columns]

# %%
dev.loc['Kung Fu Panda 3\xc2\xa0']
# Out:
# movie_title                                     Kung Fu Panda 3
# storyline      When Po's long-lost panda father suddenly reap...
# Drama                                                          0
# Comedy                                                         1
# Thriller                                                       0
# Action                                                         1
# Romance                                                        0
# Adventure                                                      1
# Crime                                                          0
# Sci-Fi                                                         0
# Fantasy                                                        0
# Horror                                                         0
# Family                                                         1
# Mystery                                                        0
# Biography                                                      0
# Animation                                                      1
# Music                                                          0
# War                                                            0
# History                                                        0
# Sport                                                          0
# Musical                                                        0
# Documentary                                                    0
# Western                                                        0
# Others                                                         0
# Name: Kung Fu Panda 3 , dtype: object

# %%
dev.loc['Kung Fu Panda 3\xc2\xa0']['storyline']
# Out:
# "When Po's long-lost panda father suddenly reappears, the reunited duo travels to a secret panda paradise to meet scores of hilarious new panda characters. But when the supernatural villain Kai begins to sweep across China defeating all the kung fu masters, Po must do the impossible-learn to train a village full of his fun-loving, clumsy brethren to become the ultimate band of Kung Fu Pandas."

# %% [markdown]
# ## Thoughts
# 1. Use web scraping to pull scripts of each movie - might be a better representative of the style
# 2. Pull more data points(movies) from IMDB - the training data is too small compared to the number of classes(right now around 4000 movies for 22 genres, ideally 1000 movies per genre)
# 3. Use pre-trained word2vec from Google to see if the testing accuracy can increase
# 4. Figure out why the training loss keeps increasing after a few thousand steps (Is the learning rate still high? Is it because of the random initialization?)
#     - Try the label smoothing method as mentioned [here](https://github.com/dennybritz/cnn-text-classification-tf/issues/56)
# 5. How to get doc2vec from this model???
